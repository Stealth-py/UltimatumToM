# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm
import numpy as np
import json
import os
import pandas as pd
from ast import literal_eval
from metrics import *

# %%
ds_p = []
ds_a_r = []
ds_r_r = []

for model in os.listdir('outs'):
    if not os.path.isdir(f'outs/{model}'):
        continue
    for prop_belief, resp_belief in [('greedy', 'fair'), ('fair', 'greedy'), ('greedy', 'greedy'), ('selfless', 'greedy'), ('selfless', 'fair'), ('greedy', 'selfless'), ('fair', 'fair'), ('fair', 'selfless'), ('selfless', 'selfless')]:
        if prop_belief == "fair":
            prop_exp = [5]
        elif prop_belief == "greedy":
            prop_exp = [7, 8, 9, 10]
        elif prop_belief == "selfless":
            prop_exp = [0, 1, 2, 3]
        
        if resp_belief == "fair":
            resp_exp = [5]
        elif resp_belief == "greedy":
            resp_exp = [6, 7, 8, 9, 10]
        elif resp_belief == "selfless":
            resp_exp = [0, 1, 2, 3, 4]

        dir_ = f'simulations/{model}/{prop_belief}-{resp_belief}'
        for exp_type in os.listdir(dir_):
            curr_dir = os.path.join(dir_, exp_type)
            print(curr_dir)
            if not os.path.isdir(curr_dir):
                continue
            for run in os.listdir(curr_dir):
                curr_d = json.load(open(os.path.join(curr_dir, run), 'r'))

                first_split = extract_split(curr_d[0]["proposer"])[0]
                dev_prop = min(abs(first_split - min(prop_exp)), abs(first_split - max(prop_exp)))
                
                ds_p.append([dev_prop, model, prop_belief, resp_belief, exp_type.replace('belief_private_', '')])

                for turn in curr_d:
                    if "accept" in turn["responder"].lower():
                        acc_split = extract_split(turn['proposer'])[-1]
                        if prop_belief == "fair":
                            if max(resp_exp) >= acc_split >= min(resp_exp):
                                dev_resp = 0
                            else:
                                dev_resp = min(abs(acc_split - min(resp_exp)), abs(acc_split - max(resp_exp)))
                            ds_a_r.append([dev_resp, model, prop_belief, resp_belief, exp_type.replace('belief_private_', '')])
                        else:
                            if max(resp_exp) >= acc_split >= min(resp_exp):
                                dev_resp = 0
                            else:
                                dev_resp = min(abs(acc_split - min(resp_exp)), abs(acc_split - max(resp_exp)))
                            ds_a_r.append([dev_resp, model, prop_belief, resp_belief, exp_type.replace('belief_private_', '')])
                        break
                    else:
                        rej_split = extract_split(turn['proposer'])[-1]
                        if resp_belief == "fair":
                            if max(resp_exp) >= rej_split >= min(resp_exp):
                                dev_resp = 0
                            else:
                                dev_resp = min(abs(rej_split - min(resp_exp)), abs(rej_split - max(resp_exp)))
                        else:    
                            if max(resp_exp) >= rej_split >= min(resp_exp):
                                dev_resp = 0
                            else:
                                dev_resp = min(abs(rej_split - min(resp_exp)), abs(rej_split - max(resp_exp)))
                        ds_r_r.append([dev_resp, model, prop_belief, resp_belief, exp_type.replace('belief_private_', '')])
# Out:
# simulations/llama-3.1-8b-instant/greedy-fair/belief_private_tom-both
# simulations/llama-3.1-8b-instant/greedy-fair/belief_private_tom-zero
# simulations/llama-3.1-8b-instant/greedy-fair/belief_private_vanilla
# simulations/llama-3.1-8b-instant/greedy-fair/belief_private_tom-first
# simulations/llama-3.1-8b-instant/greedy-fair/belief_private_cot
# simulations/llama-3.1-8b-instant/fair-greedy/belief_private_tom-both
# simulations/llama-3.1-8b-instant/fair-greedy/belief_private_tom-zero
# simulations/llama-3.1-8b-instant/fair-greedy/belief_private_vanilla
# simulations/llama-3.1-8b-instant/fair-greedy/belief_private_tom-first
# simulations/llama-3.1-8b-instant/fair-greedy/belief_private_cot
# simulations/llama-3.1-8b-instant/greedy-greedy/belief_private_tom-both
# simulations/llama-3.1-8b-instant/greedy-greedy/belief_private_tom-zero
# simulations/llama-3.1-8b-instant/greedy-greedy/belief_private_vanilla
# simulations/llama-3.1-8b-instant/greedy-greedy/belief_private_tom-first
# ...

# %%
ds_p = []
ds_a_r = []
ds_r_r = []

for model in os.listdir('test_env'):
    if not os.path.isdir(f'test_env/{model}'):
        continue
    for prop_belief, resp_belief in [('greedy', 'fair'), ('fair', 'greedy'), ('greedy', 'greedy'), ('selfless', 'greedy'), ('selfless', 'fair'), ('greedy', 'selfless'), ('fair', 'fair'), ('fair', 'selfless'), ('selfless', 'selfless')]:
        if prop_belief == "fair":
            prop_exp = [5]
        elif prop_belief == "greedy":
            prop_exp = [7, 8, 9, 10]
        elif prop_belief == "selfless":
            prop_exp = [0, 1, 2, 3]
        
        if resp_belief == "fair":
            resp_exp = [5]
        elif resp_belief == "greedy":
            resp_exp = [6, 7, 8, 9, 10]
        elif resp_belief == "selfless":
            resp_exp = [0, 1, 2, 3, 4]

        dir_ = f'test_env/{model}/{prop_belief}-{resp_belief}'
        for exp_type in os.listdir(dir_):
            curr_dir = os.path.join(dir_, exp_type)
            print(curr_dir)
            if not os.path.isdir(curr_dir):
                continue
            for run in os.listdir(curr_dir):
                curr_d = json.load(open(os.path.join(curr_dir, run), 'r'))

                first_split = extract_split(curr_d[0]["proposer"])[0]
                dev_prop = min(abs(first_split - min(prop_exp)), abs(first_split - max(prop_exp)))
                
                ds_p.append([dev_prop, model, prop_belief, resp_belief, exp_type.replace('belief_private_', '')])

                for turn in curr_d:
                    if "accept" in turn["responder"].lower():
                        acc_split = extract_split(turn['proposer'])[-1]
                        if prop_belief == "fair":
                            if max(resp_exp) >= acc_split >= min(resp_exp):
                                dev_resp = 0
                            else:
                                dev_resp = min(abs(acc_split - min(resp_exp)), abs(acc_split - max(resp_exp)))
                            ds_a_r.append([dev_resp, model, prop_belief, resp_belief, exp_type.replace('belief_private_', '')])
                        else:
                            if max(resp_exp) >= acc_split >= min(resp_exp):
                                dev_resp = 0
                            else:
                                dev_resp = min(abs(acc_split - min(resp_exp)), abs(acc_split - max(resp_exp)))
                            ds_a_r.append([dev_resp, model, prop_belief, resp_belief, exp_type.replace('belief_private_', '')])
                        break
                    else:
                        rej_split = extract_split(turn['proposer'])[-1]
                        if resp_belief == "fair":
                            if max(resp_exp) >= rej_split >= min(resp_exp):
                                dev_resp = 0
                            else:
                                dev_resp = min(abs(rej_split - min(resp_exp)), abs(rej_split - max(resp_exp)))
                        else:    
                            if max(resp_exp) >= rej_split >= min(resp_exp):
                                dev_resp = 0
                            else:
                                dev_resp = min(abs(rej_split - min(resp_exp)), abs(rej_split - max(resp_exp)))
                        ds_r_r.append([dev_resp, model, prop_belief, resp_belief, exp_type.replace('belief_private_', '')])
# Out:
# test_env/gpt-4o/greedy-fair/belief_private_tom-both
# test_env/gpt-4o/greedy-fair/belief_private_tom-zero
# test_env/gpt-4o/greedy-fair/belief_private_tom-first
# test_env/gpt-4o/fair-greedy/belief_private_tom-both
# test_env/gpt-4o/fair-greedy/belief_private_tom-zero
# test_env/gpt-4o/fair-greedy/belief_private_tom-first
# test_env/gpt-4o/greedy-greedy/belief_private_tom-both
# test_env/gpt-4o/greedy-greedy/belief_private_tom-zero
# test_env/gpt-4o/greedy-greedy/belief_private_tom-first
# test_env/gpt-4o/selfless-greedy/belief_private_tom-both
# test_env/gpt-4o/selfless-greedy/belief_private_tom-zero
# test_env/gpt-4o/selfless-greedy/belief_private_tom-first
# test_env/gpt-4o/selfless-fair/belief_private_tom-both
# test_env/gpt-4o/selfless-fair/belief_private_tom-zero
# test_env/gpt-4o/selfless-fair/belief_private_tom-first
# test_env/gpt-4o/greedy-selfless/belief_private_tom-both
# test_env/gpt-4o/greedy-selfless/belief_private_tom-zero
# ...

# %%
df_p = pd.DataFrame(ds_p, columns=['DS', 'Model', 'Prop Belief', 'Resp Belief', 'Reasoning'])
df_a_r = pd.DataFrame(ds_a_r, columns=['DS', 'Model', 'Prop Belief', 'Resp Belief', 'Reasoning'])
df_r_r = pd.DataFrame(ds_r_r, columns=['DS', 'Model', 'Prop Belief', 'Resp Belief', 'Reasoning'])

# %%
df_p.sort_values('DS', inplace=True)
df_a_r.sort_values('DS', inplace=True)
df_r_r.sort_values('DS', inplace=True)

# %%
# df_p.to_csv('prop_dev.csv')
# df_a_r.to_csv('resp_acc_dev.csv')
# df_r_r.to_csv('resp_rej_dev.csv')

# %%
# df_p = pd.read_csv('prop_dev.csv')
# df_a_r = pd.read_csv('resp_acc_dev.csv')
# df_r_r = pd.read_csv('resp_rej_dev.csv')

# %%
df_p.columns=['DS', 'Model', 'prop_belief', 'resp_belief', 'Reasoning']
df_a_r.columns=['DS', 'Model', 'prop_belief', 'resp_belief', 'Reasoning']
df_r_r.columns=['DS', 'Model', 'prop_belief', 'resp_belief', 'Reasoning']

# %%
df_p = sm.add_constant(df_p, prepend=False)
df_a_r = sm.add_constant(df_a_r, prepend=False)
df_r_r = sm.add_constant(df_r_r, prepend=False)

# %%
df_p.Model.unique()
# Out:
# array(['gpt-4o'], dtype=object)

# %% [markdown]
# ## With Beliefs

# %%
belief_formula = 'DS ~ C(Model) + C(Reasoning) + C(prop_belief) + C(resp_belief)'

# %%
model_p_bel = smf.ols(formula=belief_formula, data=df_p).fit()
print(model_p_bel.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     DS   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.108
# Method:                 Least Squares   F-statistic:                     6.411
# Date:                Tue, 18 Mar 2025   Prob (F-statistic):           2.55e-06
# Time:                        15:10:39   Log-Likelihood:                -126.21
# No. Observations:                 270   AIC:                             266.4
# Df Residuals:                     263   BIC:                             291.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.0037      0.063      0.059      0.953      -0.120       0.128
# ...

# %%
model_a_r_bel = smf.ols(formula=belief_formula, data=df_a_r).fit()
print(model_a_r_bel.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     DS   R-squared:                       0.387
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     25.68
# Date:                Tue, 18 Mar 2025   Prob (F-statistic):           1.37e-23
# Time:                        15:10:39   Log-Likelihood:                -373.95
# No. Observations:                 251   AIC:                             761.9
# Df Residuals:                     244   BIC:                             786.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.2119      0.180      1.180      0.239      -0.142       0.566
# ...

# %%
model_r_r_bel = smf.ols(formula=belief_formula, data=df_r_r).fit()
print(model_r_r_bel.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     DS   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                     46.62
# Date:                Tue, 18 Mar 2025   Prob (F-statistic):           8.28e-44
# Time:                        15:10:40   Log-Likelihood:                -819.21
# No. Observations:                 431   AIC:                             1652.
# Df Residuals:                     424   BIC:                             1681.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      2.5571      0.326      7.842      0.000       1.916       3.198
# ...

# %% [markdown]
# ## Without Beliefs

# %%
# Define formulas 
formula_p = 'DS ~ C(Model) + C(Reasoning)'
formula_a_r = 'DS ~ C(Model) + C(Reasoning)'
formula_r_r = 'DS ~ C(Model) + C(Reasoning)'

# %%
# OLS for prop_dev.csv 
model_p = smf.ols(formula=formula_p, data=df_p).fit()
print(model_p.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     DS   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     44.34
# Date:                Fri, 14 Mar 2025   Prob (F-statistic):           9.75e-75
# Time:                        10:02:08   Log-Likelihood:                -2738.8
# No. Observations:                2700   AIC:                             5498.
# Df Residuals:                    2690   BIC:                             5557.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# OLS for prop_dev.csv 
model_a_r = smf.ols(formula=formula_a_r, data=df_a_r).fit()
print(model_a_r.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     DS   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     11.94
# Date:                Fri, 14 Mar 2025   Prob (F-statistic):           1.33e-18
# Time:                        10:00:31   Log-Likelihood:                -4526.9
# No. Observations:                2424   AIC:                             9074.
# Df Residuals:                    2414   BIC:                             9132.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
# OLS for prop_dev.csv 
model_r_r = smf.ols(formula=formula_r_r, data=df_r_r).fit()
print(model_r_r.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     DS   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     14.93
# Date:                Fri, 14 Mar 2025   Prob (F-statistic):           3.52e-24
# Time:                        10:00:31   Log-Likelihood:                -9497.9
# No. Observations:                4666   AIC:                         1.902e+04
# Df Residuals:                    4656   BIC:                         1.908e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...
